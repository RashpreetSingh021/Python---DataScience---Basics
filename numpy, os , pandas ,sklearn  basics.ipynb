# %%
import numpy as np

# %%
arr=np.random.random((3,4))

# %%
np.arange(1,100,8)     # n0.s btw 1 - 100 with the gap of 8 (3rd pramtr)      .arrange(start, end , gap)
# Out:
# array([ 1,  9, 17, 25, 33, 41, 49, 57, 65, 73, 81, 89, 97])

# %%
np.linspace(1,10,5)   # (3rd pramtr) 5 no.s btw 1(1st pramtr) to 10(2nd pramtr) with same gap    .linespace(start , end , total no.s)
# Out:
# array([ 1.  ,  3.25,  5.5 ,  7.75, 10.  ])

# %%
arr
# Out:
# array([[0.65212524, 0.0383785 , 0.26643751, 0.21482247],
#        [0.08279613, 0.77796227, 0.78979238, 0.08543572],
#        [0.47150626, 0.68621129, 0.7058172 , 0.23116622]])

# %%
np.reshape(arr,(6,2))
# Out:
# array([[0.65212524, 0.0383785 ],
#        [0.26643751, 0.21482247],
#        [0.08279613, 0.77796227],
#        [0.78979238, 0.08543572],
#        [0.47150626, 0.68621129],
#        [0.7058172 , 0.23116622]])

# %%
arr
# Out:
# array([[0.65212524, 0.0383785 , 0.26643751, 0.21482247],
#        [0.08279613, 0.77796227, 0.78979238, 0.08543572],
#        [0.47150626, 0.68621129, 0.7058172 , 0.23116622]])

# %%
arr.max(axis=0)#max for each col
# Out:
# array([0.65212524, 0.77796227, 0.78979238, 0.23116622])

# %%
arr.max(axis=1)#max for each row
# Out:
# array([0.65212524, 0.78979238, 0.7058172 ])

# %%
arr.min(axis=0)#max for each col
# Out:
# array([0.08279613, 0.0383785 , 0.26643751, 0.08543572])

# %%
arr.min(axis=1)#min for each row
# Out:
# array([0.0383785 , 0.08279613, 0.23116622])

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is DCC5-62E7
#
#  Directory of C:\Users\rashp
#
# 01/08/2023  02:35 AM    <DIR>          .
# 01/07/2023  02:27 PM    <DIR>          ..
# 01/08/2023  04:12 AM    <DIR>          .conda
# 01/07/2023  03:19 PM                25 .condarc
# 01/07/2023  03:19 PM    <DIR>          .continuum
# 01/08/2023  02:13 AM    <DIR>          .ipynb_checkpoints
# 01/07/2023  07:56 PM    <DIR>          .ipython
# 01/07/2023  03:36 PM    <DIR>          .jupyter
# 01/07/2023  03:20 PM    <DIR>          anaconda3
# 01/07/2023  02:45 PM    <DIR>          Contacts
# 01/08/2023  12:12 AM             4,108 create bulk directories.ipynb
# 01/08/2023  12:10 AM    <DIR>          Documents
# 01/07/2023  09:30 PM    <DIR>          Downloads
# 01/07/2023  02:45 PM    <DIR>          Favorites
# 01/07/2023  02:45 PM    <DIR>          Links
# 01/07/2023  02:45 PM    <DIR>          Music
# 01/08/2023  01:00 AM    <DIR>          OneDrive
# ...

# %%
import os

# %%
os.chdir('course_data_file')

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is DCC5-62E7
#
#  Directory of C:\Users\rashp\course_data_file
#
# 01/08/2023  04:38 AM    <DIR>          .
# 01/08/2023  04:21 PM    <DIR>          ..
# 01/08/2023  04:22 AM         1,360,155 datafile.csv
# 01/08/2023  04:15 AM         1,360,155 datafile.txt
#                2 File(s)      2,720,310 bytes
#                2 Dir(s)  386,100,436,992 bytes free

# %%
import pandas as pd

# %%
data = pd.read_csv('datafile.csv')

# %%
data['App']
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: object

# %%
data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df = data.dropna()

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df1 = pd.DataFrame(data)

# %%
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df2 = df1['Category'].unique()

# %%
for i in df2:
    print(i)
# Out:
# ART_AND_DESIGN
# AUTO_AND_VEHICLES
# BEAUTY
# BOOKS_AND_REFERENCE
# BUSINESS
# COMICS
# COMMUNICATION
# DATING
# EDUCATION
# ENTERTAINMENT
# EVENTS
# FINANCE
# FOOD_AND_DRINK
# HEALTH_AND_FITNESS
# HOUSE_AND_HOME
# LIBRARIES_AND_DEMO
# LIFESTYLE
# GAME
# FAMILY
# MEDICAL
# SOCIAL
# SHOPPING
# PHOTOGRAPHY
# SPORTS
# TRAVEL_AND_LOCAL
# TOOLS
# PERSONALIZATION
# PRODUCTIVITY
# PARENTING
# WEATHER
# VIDEO_PLAYERS
# NEWS_AND_MAGAZINES
# MAPS_AND_NAVIGATION
# 1.9

# %%
# #dealing with null..not simply removing it.
# sklearn   from sklearn.impute import simpleImputer

# %%
df = pd.read_csv('datafile.csv')

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
imputer.fit(df.iloc[:,2:3])
# Out:
# SimpleImputer()

# %%
df.iloc[:,2:3] = imputer.transform(df.iloc[:,2:3])

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# dtype: int64

# %%
df = df.dropna()

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# to deal with null by imputing mean/median/mode values on null
import numpy as np
import pandas as pd

from sklearn.impute import SimpleImputer    #to compute fit and transform the values and apply *mean* on them or *median* or *most frequent*

df = pd.read_csv('datafile.csv')
#df.isnull().sum()                    #used to check and give no of null values in each categories

impute = SimpleImputer(missing_values = np.nan, strategy = 'mean')

impute.fit(df.iloc[ : , 2:3 ])


df.iloc[:,2:3] = impute.transform(df.iloc[ : , 2:3 ])  #to get values of rating locating at col 2nd


df.isnull().sum()

df = df.dropna()  #to drop is null found

df.isnull().sum()

df.head(20)  #standard 5..or given user defiend value
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# ...

# %%
#this to deal full data's null value with imputing mode(most frequent) at d place of null

import numpy as np
import pandas as pd

from sklearn.impute import SimpleImputer    #to compute fit and transform the values and apply *mean* on them or *median* or *most frequent*

df = pd.read_csv('datafile.csv')
#df
df.isnull().sum()                    #used to check and give no of null values in each categories

impute = SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')

impute.fit(df.iloc[ : , : ])


df.iloc[:,:] = impute.transform(df.iloc[ : , : ])  #to get values of rating locating at col 2nd


df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# #to check what all apps are free ..there name and count and should of same category and rating should be 4.5 and more

# %%
df1 = df.values
#df[0]

# %%
df1[0]
# Out:
# array(['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN',
#        4.1, '159', '19M', '10,000+', 'Free', '0', 'Everyone',
#        'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up'],
#       dtype=object)

# %%
c=0
print('--'*20)
for i in df1:
    if i[1] == 'ART_AND_DESIGN' and i[2] >=4.5  and i[6] == 'Free':
        c +=1
        print(i[0])
        print('-'*10)
print('--'*20)
print('There are {c} app of category ART_AND_DESIGN and also free and of rating = or more than 4.5')
# Out:
# ----------------------------------------
# U Launcher Lite – FREE Live Cool Themes, Hide Apps
# ----------
# Sketch - Draw & Paint
# ----------
# Kids Paint Free - Drawing Fun
# ----------
# Mandala Coloring Book
# ----------
# Photo Designer - Write your name with shapes
# ----------
# 350 Diy Room Decor Ideas
# ----------
# ibis Paint X
# ----------
# Superheroes Wallpapers | 4K Backgrounds
# ----------
# HD Mickey Minnie Wallpapers
# ----------
# Harley Quinn wallpapers HD
# ----------
# Colorfit - Drawing & Coloring
# ----------
# Anime Manga Coloring Book
# ----------
# I Creative Idea
# ----------
# UNICORN - Color By Number & Pixel Art Coloring
# ----------
# PIP Camera - PIP Collage Maker
# ----------
# Sad Poetry Photo Frames 2018
# ----------
# Canva: Poster, banner, card maker & graphic design
# ----------
# Install images with music to make video without Net - 2018
# ----------
# Cardi B Wallpaper
# ----------
# X Launcher: With OS11 Style Theme & Control Center
# ...

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# # Easy method to do above task

# %%
df_ct = df[df['Category'] == 'ART_AND_DESIGN'] #df_ct =category which i want

# %%
df_rt = df_ct[df_ct['Rating'] >= 4.5] #df_rt is all the apps having category and rating which i want

# %%
df_final = df_rt[df_rt['Type'] == 'Free']

# %%
df_final #all the apps of ART_AND_DESIGN ,free and rating =>4.5
# Out:
#                                                     App        Category  \
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 9                         Kids Paint Free - Drawing Fun  ART_AND_DESIGN
# 13                                Mandala Coloring Book  ART_AND_DESIGN
# 16         Photo Designer - Write your name with shapes  ART_AND_DESIGN
# 17                             350 Diy Room Decor Ideas  ART_AND_DESIGN
# 19                                         ibis Paint X  ART_AND_DESIGN
# 22              Superheroes Wallpapers | 4K Backgrounds  ART_AND_DESIGN
# 24                          HD Mickey Minnie Wallpapers  ART_AND_DESIGN
# 25                           Harley Quinn wallpapers HD  ART_AND_DESIGN
# 26                        Colorfit - Drawing & Coloring  ART_AND_DESIGN
# 32                            Anime Manga Coloring Book  ART_AND_DESIGN
# ...

# %% [markdown]
# # Groupby usage for more complexicity

# %% [markdown]
# ### Q1 Which category having max  avg rating

# %%
df['Category'].unique()#in sb k ratings k avg nikalna h
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df[df['Category'] == '1.9']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone       Everyone  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up  4.1 and up

# %%
df.groupby('Category').mean()['Rating'].sort_values(ascending = True)
# Out:
# Category
# DATING                  4.042308
# MAPS_AND_NAVIGATION     4.084672
# VIDEO_PLAYERS           4.092571
# TOOLS                   4.093001
# ENTERTAINMENT           4.126174
# TRAVEL_AND_LOCAL        4.145349
# LIFESTYLE               4.149215
# COMICS                  4.163333
# FINANCE                 4.163388
# NEWS_AND_MAGAZINES      4.179505
# COMMUNICATION           4.195349
# FOOD_AND_DRINK          4.200000
# PHOTOGRAPHY             4.203284
# FAMILY                  4.215974
# BUSINESS                4.216522
# AUTO_AND_VEHICLES       4.220000
# HOUSE_AND_HOME          4.225000
# LIBRARIES_AND_DEMO      4.230588
# MEDICAL                 4.240605
# PRODUCTIVITY            4.243868
# SPORTS                  4.253385
# WEATHER                 4.257317
# SHOPPING                4.271538
# SOCIAL                  4.273220
# GAME                    4.290997
# HEALTH_AND_FITNESS      4.292962
# BEAUTY                  4.303774
# PARENTING               4.316667
# ...
